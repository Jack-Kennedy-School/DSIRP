# %% [markdown]
# # Algorithms

# %% [markdown]
# [Click here to run this chapter on Colab](https://colab.research.google.com/github/AllenDowney/DSIRP/blob/main/notebooks/algorithms.ipynb)

# %% [markdown]
# ## Searching for anagrams
#
# In this notebook we'll implement algorithms for two tasks:
#
# * Testing a pair of words to see if they are anagrams of each other, that is, if you can rearrange the letters in one word to spell the other.
#
# * Searching a list of words for all pairs that are anagrams of each other.
#
# There is a point to these examples, which I will explain at the end.

# %% [markdown]
# **Exercise 1:** Write a function that takes two words and returns `True` if they are anagrams. Test your function with the examples below.

# %%
def is_anagram(word1, word2):
    return False

# %%
is_anagram('tachymetric', 'mccarthyite') # True
# Out:
# False

# %%
is_anagram('post', 'top') # False, letter not present
# Out:
# False

# %%
is_anagram('pott', 'top') # False, letter present but not enough copies
# Out:
# False

# %%
is_anagram('top', 'post') # False, letters left over at the end
# Out:
# False

# %%
is_anagram('topss', 'postt') # False
# Out:
# False

# %% [markdown]
# **Exercise 2:** Use `timeit` to see how fast your function is for these examples:

# %%
# %timeit is_anagram('tops', 'spot')
# Out:
# 133 ns ± 10.5 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %%
# %timeit is_anagram('tachymetric', 'mccarthyite')
# Out:
# 135 ns ± 2.06 ns per loop (mean ± std. dev. of 7 runs, 10,000,000 loops each)

# %% [markdown]
# How can we compare algorithms running on different computers?

# %% [markdown]
# ## Searching for anagram pairs

# %% [markdown]
# **Exercise 3:** Write a function that takes a word list and returns a list of all anagram pairs.

# %%
short_word_list = ['proudest', 'stop', 'pots', 'tops', 'sprouted']

# %%
def all_anagram_pairs(word_list):
    for word in word_list:
        for otherword in word_list:
            if(sorted(word)== sorted(otherword)):
                print(word + " " + otherword)

# %%
all_anagram_pairs(short_word_list)
# Out:
# proudest proudest
# proudest sprouted
# stop stop
# stop pots
# stop tops
# pots stop
# pots pots
# pots tops
# tops stop
# tops pots
# tops tops
# sprouted proudest
# sprouted sprouted

# %% [markdown]
# The following cell downloads a file containing a list of English words.

# %%
from os.path import basename, exists

def download(url):
    filename = basename(url)
    if not exists(filename):
        from urllib.request import urlretrieve
        local, _ = urlretrieve(url, filename)
        print('Downloaded ' + local)
    
download('https://github.com/AllenDowney/DSIRP/raw/main/american-english')
# Out:
# Downloaded american-english

# %% [markdown]
# The following function reads a file and returns a set of words (I used a set because after we convert words to lower case, there are some repeats.)

# %%
def read_words(filename):
    """Read lines from a file and split them into words."""
    res = set()
    for line in open(filename):
        for word in line.split():
            res.add(word.strip().lower())
    return res

# %%
word_list = read_words('american-english')
len(word_list)
# Out:
# 100781

# %% [markdown]
# **Exercise 4:** Loop through the word list and print all words that are anagrams of `stop`.

# %%
for word in word_list:
    if(sorted('stop')== sorted(word)):
        print(word)
# Out:
# tops
# post
# stop
# spot
# opts
# pots

# %% [markdown]
# Now run `all_anagram_pairs` with the full `word_list`:

# %%
pairs = all_anagram_pairs(word_list)
# Out:
# forehead's forehead's
# crookedness crookedness
# foamier foamier
# ariosto's ariosto's
# appeasement's appeasement's
# irreverence's irreverence's
# optimization optimization
# needful needful
# ventricular ventricular
# nostalgia's nostalgia's
# ecstatic ecstatic
# whined whined
# potomac potomac
# chant chant
# alumna's alumna's
# alumna's manual's
# bruises bruises
# crippled crippled
# comebacks comebacks
# centralization centralization
# saccharin's saccharin's
# durkheim durkheim
# acidifying acidifying
# walnut's walnut's
# encore's encore's
# jeanie jeanie
# methuselah's methuselah's
# outplaying outplaying
# unrefined unrefined
# aversion aversion
# anaesthetic's anaesthetic's
# millicent millicent
# yearns yearns
# afterglow's afterglow's
# reasonableness's reasonableness's
# crete's crete's
# agile agile
# medicaid's medicaid's
# bier's bier's
# bier's brie's
# dazes dazes
# dazes adzes
# triplicating triplicating
# jeep's jeep's
# imperfects imperfects
# disk disk
# disk skid
# disk kids
# bulwarks bulwarks
# jujube's jujube's
# spandex spandex
# spandex expands
# goodbyes goodbyes
# rust's rust's
# vicing vicing
# forerunners forerunners
# tribune's tribune's
# tribune's turbine's
# new's new's
# new's wen's
# unrolled unrolled
# idyl's idyl's
# sars's sars's
# datives datives
# disorder's disorder's
# intermediaries intermediaries
# kneel kneel
# escalate escalate
# derrières derrières
# threshold's threshold's
# chichi's chichi's
# requested requested
# milkshake's milkshake's
# signalling signalling
# instep's instep's
# instep's spinet's
# unlock unlock
# unsealed unsealed
# mountaineer mountaineer
# mountaineer enumeration
# dustman dustman
# fuselage fuselage
# cortex cortex
# elegy elegy
# revives revives
# hulking hulking
# teakettle's teakettle's
# firefly firefly
# sternly sternly
# grandchildren's grandchildren's
# pluperfect's pluperfect's
# silly's silly's
# bandwagon's bandwagon's
# hassocks hassocks
# browse's browse's
# browse's bowers's
# dampness's dampness's
# pique pique
# pique equip
# liquidating liquidating
# appellation's appellation's
# preexist preexist
# knowledgeable knowledgeable
# achieving achieving
# yank yank
# anarchically anarchically
# outfoxes outfoxes
# parenthood parenthood
# ernest's ernest's
# ernest's sterne's
# munch's munch's
# licorice licorice
# extraordinary extraordinary
# napkin napkin
# saxophones saxophones
# altars altars
# altars astral
# anyone's anyone's
# justices justices
# kiss's kiss's
# longtime longtime
# psychoanalysts psychoanalysts
# toadied toadied
# instance's instance's
# entertainer's entertainer's
# festivity's festivity's
# caroled caroled
# facsimile's facsimile's
# avenge avenge
# avenge geneva
# ripley ripley
# ripley ripely
# bedraggling bedraggling
# caramel's caramel's
# caramel's carmela's
# incidences incidences
# tastiness tastiness
# hurdler's hurdler's
# summered summered
# paleolithic's paleolithic's
# likelihoods likelihoods
# indictments indictments
# jennifer jennifer
# flounce flounce
# dante dante
# dante anted
# tipples tipples
# tipples stipple
# sumach's sumach's
# hideaway hideaway
# unexplored unexplored
# openly openly
# haze haze
# dole dole
# dole lode
# squaw's squaw's
# johannes johannes
# flagstone's flagstone's
# butchers butchers
# butchers schubert
# crowdfunded crowdfunded
# lesotho's lesotho's
# headlands headlands
# gob's gob's
# gob's bog's
# pregnancy's pregnancy's
# earnests earnests
# oxbows oxbows
# taproots taproots
# literacy literacy
# addled addled
# dennis's dennis's
# precepts precepts
# antedating antedating
# code's code's
# code's coed's
# druggists druggists
# uncollected uncollected
# craps's craps's
# craps's scrap's
# stratifying stratifying
# hood hood
# refereeing refereeing
# rekindles rekindles
# sixty sixty
# karakul's karakul's
# panier panier
# panier napier
# panier rapine
# hopkins hopkins
# mismatched mismatched
# preregistered preregistered
# vulgarization's vulgarization's
# breathe breathe
# obtrude obtrude
# port port
# merchandising merchandising
# python python
# revivals revivals
# muzzles muzzles
# shadiness's shadiness's
# mountaineer's mountaineer's
# mountaineer's enumeration's
# bisections bisections
# lumpiness lumpiness
# deduced deduced
# squeegees squeegees
# unselfishly unselfishly
# jupiter's jupiter's
# heroine's heroine's
# wigwam's wigwam's
# electrolysis's electrolysis's
# inflames inflames
# bachelor bachelor
# fibbing fibbing
# soured soured
# soured roused
# australoid australoid
# beg beg
# chipmunk's chipmunk's
# desk's desk's
# casein's casein's
# plumps plumps
# renovate renovate
# espadrille espadrille
# transposition transposition
# pace pace
# pace cape
# accompaniment accompaniment
# crocodile's crocodile's
# pawed pawed
# douche's douche's
# reprized reprized
# sandblast sandblast
# wrongdoer's wrongdoer's
# repackaging repackaging
# cacaos cacaos
# telecasted telecasted
# seagram seagram
# camelopardalis's camelopardalis's
# neglig's neglig's
# neglig's niggle's
# neglig's leggin's
# melodrama melodrama
# emulsified emulsified
# appropriates appropriates
# backings backings
# cutter cutter
# enticing enticing
# schuss's schuss's
# melding melding
# melding mingled
# flashy flashy
# humidity humidity
# refurbishments refurbishments
# alphabetized alphabetized
# savageness savageness
# fijian fijian
# referee's referee's
# coif's coif's
# louisianans louisianans
# boodle's boodle's
# manumit manumit
# cornelius cornelius
# cornelius inclosure
# spectacles spectacles
# frankness frankness
# soufflé's soufflé's
# sportswoman's sportswoman's
# strived strived
# strived diverts
# gym's gym's
# hymning hymning
# accrual's accrual's
# accrual's caracul's
# astronaut astronaut
# vlasic vlasic
# vlasic cavils
# vlasic slavic
# bruise's bruise's
# convalescents convalescents
# helps helps
# helps shlep
# hopelessness's hopelessness's
# carcinomas carcinomas
# pitchmen pitchmen
# merrymaker merrymaker
# crankshafts crankshafts
# prevarication's prevarication's
# alston's alston's
# alston's salton's
# elevator elevator
# plutocratic plutocratic
# grad's grad's
# grad's drag's
# cypher cypher
# bitches bitches
# introvert's introvert's
# patents patents
# discoed discoed
# polygon's polygon's
# as as
# presentable presentable
# pandered pandered
# raquel's raquel's
# perimeter perimeter
# insensitivity insensitivity
# schoolroom schoolroom
# torch torch
# revivification revivification
# screen screen
# screen censer
# blades blades
# revel revel
# revel lever
# roguishly roguishly
# journey journey
# narrower narrower
# josie's josie's
# joyrider joyrider
# cages cages
# restorations restorations
# ship's ship's
# clobbers clobbers
# clobbers cobblers
# court court
# insures insures
# insures sunrise
# mulder mulder
# tendered tendered
# hither hither
# diann diann
# aludra's aludra's
# feed feed
# glittered glittered
# interventions interventions
# wigged wigged
# tutsi's tutsi's
# tutsi's titus's
# mars mars
# mars arms
# mars rams
# cicatrix cicatrix
# nutmeg nutmeg
# mulattos mulattos
# flanked flanked
# copeck's copeck's
# geodesics geodesics
# imprint's imprint's
# parsnips parsnips
# crocheting crocheting
# revitalized revitalized
# toddy toddy
# polyphonic polyphonic
# harrods harrods
# boss boss
# boss sobs
# stage's stage's
# stage's gates's
# beatles's beatles's
# allied allied
# naismith naismith
# organist's organist's
# afrocentrism afrocentrism
# gwendoline gwendoline
# less less
# enhance enhance
# gehenna gehenna
# gibbon's gibbon's
# yemen's yemen's
# yemen's enemy's
# auricles auricles
# fibs fibs
# dreadfully dreadfully
# accompaniments accompaniments
# cathay's cathay's
# looted looted
# looted tooled
# looted toledo
# beyer beyer
# mucilage's mucilage's
# smallest smallest
# fresh fresh
# baptists baptists
# sealer sealer
# sealer reales
# sealer resale
# increases increases
# carved carved
# carved craved
# schuss schuss
# jody's jody's
# clunker's clunker's
# decrying decrying
# adept's adept's
# accenting accenting
# grinder grinder
# rhymes rhymes
# dram dram
# contributor contributor
# herbivore herbivore
# freeways freeways
# splotched splotched
# stitched stitched
# border's border's
# reformulated reformulated
# unconsciously unconsciously
# bearable bearable
# gaily gaily
# oxidized oxidized
# pale's pale's
# pale's leap's
# pale's peal's
# pale's plea's
# concerted concerted
# concerted concreted
# pseudonyms pseudonyms
# prefixes prefixes
# glib glib
# sportsman's sportsman's
# sensationalism sensationalism
# multiplied multiplied
# hyades hyades
# liaisons liaisons
# upstate upstate
# contouring contouring
# wigs wigs
# wigs swig
# yodeller yodeller
# alpheratz's alpheratz's
# rebating rebating
# rebating berating
# multiplicand multiplicand
# ptolemaic ptolemaic
# moonlighters moonlighters
# merits merits
# merits timers
# merits mister
# merits miters
# merits remits
# cirrus cirrus
# scrip scrip
# scrip crisp
# thiamine thiamine
# familiar's familiar's
# adjurations adjurations
# sorter's sorter's
# sorter's roster's
# sorter's torres's
# sorter's resort's
# multivariate multivariate
# reinserted reinserted
# mountaineers mountaineers
# mountaineers enumerations
# extirpated extirpated
# haycock's haycock's
# jeannette's jeannette's
# bestowed bestowed
# chaldean's chaldean's
# omelets omelets
# yggdrasil yggdrasil
# personalities personalities
# oculist oculist
# raft raft
# raft frat
# raft fart
# catty catty
# mulishness's mulishness's
# timbres timbres
# timbres timbers
# glands glands
# jinnah's jinnah's
# headers adheres
# headers headers
# headers sheared
# chancellorsville's chancellorsville's
# shrubby shrubby
# depositors depositors
# devastating devastating
# confab confab
# betsy betsy
# betsy bytes
# composition composition
# bern bern
# mesmerize mesmerize
# glamorous glamorous
# macarthur macarthur
# interlard interlard
# hello's hello's
# postgresql's postgresql's
# redcoat's redcoat's
# mimicry's mimicry's
# coached coached
# knightly knightly
# collections collections
# sandwiching sandwiching
# misfit misfit
# acorn's acorn's
# formaldehyde's formaldehyde's
# folklore's folklore's
# ingested ingested
# merit merit
# merit remit
# merit miter
# merit timer
# summitry summitry
# paining paining
# real's real's
# real's earl's
# real's lear's
# behest's behest's
# behest's thebes's
# invert invert
# knacks knacks
# fushun's fushun's
# caruso's caruso's
# outgrowth's outgrowth's
# sputter sputter
# sputter putters
# workhouse workhouse
# workhouse housework
# bowling's bowling's
# inexpedient inexpedient
# energizes energizes
# surfboard's surfboard's
# partner's partner's
# hoosier hoosier
# dissolves dissolves
# nanotechnology nanotechnology
# remit merit
# remit remit
# remit miter
# remit timer
# loftiness's loftiness's
# chimu chimu
# scrapes scrapes
# scrapes parsecs
# sprucest sprucest
# standings standings
# countdowns countdowns
# leno leno
# leno lone
# leno noel
# leno leon
# leno olen
# expresses expresses
# awes awes
# doctrine's doctrine's
# embezzler's embezzler's
# partials partials
# mckee's mckee's
# worthiness worthiness
# pyrenees pyrenees
# photojournalist photojournalist
# tercentenaries tercentenaries
# etched etched
# uppity uppity
# temblors temblors
# sabbatical's sabbatical's
# roomful's roomful's
# pueblos pueblos
# equipped equipped
# bodhidharma's bodhidharma's
# frenchwomen frenchwomen
# dumbledore's dumbledore's
# empty empty
# pullers pullers
# culminating culminating
# pushovers pushovers
# mynahes mynahes
# maribel maribel
# maribel balmier
# cohabit cohabit
# tragedians tragedians
# bevel bevel
# pledge's pledge's
# alcott alcott
# facility facility
# haney's haney's
# haney's hyena's
# abuser abuser
# hilariously hilariously
# indolent indolent
# stupider stupider
# rubbing rubbing
# brahms brahms
# basics basics
# valving valving
# employer's employer's
# hughes's hughes's
# retching retching
# directness directness
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [20], line 1
# ----> 1 pairs = all_anagram_pairs(word_list)
#
# Cell In [18], line 4, in all_anagram_pairs(word_list)
#       2 for word in word_list:
#       3     for otherword in word_list:
# ----> 4         if(sorted(word)== sorted(otherword)):
#       5             print(word + " " + otherword)
#
# KeyboardInterrupt:

# %% [markdown]
# **Exercise 5:** While that's running, let's estimate how long it's going to take.

# %%
# %timeit all_anagram_pairs(word_list)
# Out:
# forehead's forehead's
# crookedness crookedness
# foamier foamier
# ariosto's ariosto's
# appeasement's appeasement's
# irreverence's irreverence's
# optimization optimization
# needful needful
# ventricular ventricular
# nostalgia's nostalgia's
# ecstatic ecstatic
# whined whined
# potomac potomac
# chant chant
# alumna's alumna's
# alumna's manual's
# bruises bruises
# crippled crippled
# comebacks comebacks
# centralization centralization
# saccharin's saccharin's
# baaed baaed
# aachen aachen
# pretentious pretentious
# vitals vitals
# brevity's brevity's
# docudramas docudramas
# responsibilities responsibilities
# pugh pugh
# impeach impeach
# tunefully tunefully
# socialists socialists
# upset's upset's
# upset's setup's
# atheism's atheism's
# calendared calendared
# cognitive cognitive
# shlepp shlepp
# shlepp phelps
# jazz jazz
# spartans spartans
# softened softened
# winning's winning's
# neal neal
# neal lane
# neal lean
# neal lena
# pompously pompously
# hemophiliac hemophiliac
# pizarro pizarro
# elena elena
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 get_ipython().run_line_magic('timeit', 'all_anagram_pairs(word_list)')
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:2364, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2362     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2363 with self.builtin_trap:
# -> 2364     result = fn(*args, **kwargs)
#    2365 return result
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/magics/execution.py:1162, in ExecutionMagics.timeit(self, line, cell, local_ns)
#    1160 for index in range(0, 10):
#    1161     number = 10 ** index
# -> 1162     time_number = timer.timeit(number)
#    1163     if time_number >= 0.2:
#    1164         break
#
# File ~/Library/Python/3.9/lib/python/site-packages/IPython/core/magics/execution.py:156, in Timer.timeit(self, number)
#     154 gc.disable()
#     155 try:
# --> 156     timing = self.inner(it, self.timer)
#     157 finally:
#     158     if gcold:
#
# File <magic-timeit>:1, in inner(_it, _timer)
#
# Cell In [18], line 4, in all_anagram_pairs(word_list)
#       2 for word in word_list:
#       3     for otherword in word_list:
# ----> 4         if(sorted(word)== sorted(otherword)):
#       5             print(word + " " + otherword)
#
# KeyboardInterrupt:

# %% [markdown]
# ## A better algorithm
#
# **Exercise 6:** Write a better algorithm! Hint: make a dictionary. How much faster is your algorithm?

# %%
def is_anagram(list_of_str):

    new_list = []
    empty_dict ={}
    
    for item in list_of_str:
        sorted_item = ''.join(sorted(item))
        if sorted_item not in empty_dict:
            empty_dict[sorted_item] = [item]
        else:
            empty_dict[sorted_item].append(item)
    for k,v in empty_dict.items():
        if len(v)>=2:
            new_list.append(v)
    return new_list

#a = ['dog', 'god', 'cat']
#print(is_anagram(a))

# %%
print(is_anagram(word_list))

# %%
# %time anagram_map = is_anagram(word_list)
# Out:
# CPU times: user 293 ms, sys: 24.7 ms, total: 317 ms
# Wall time: 361 ms

# %%
len(anagram_map)
# Out:
# 5872

# %%
# Out:
# ['tesla', 'tales', 'steal', 'slate', 'stale', 'least', 'stael', 'teals']

# %% [markdown]
# ## Summary
#
# What is the point of the examples in this notebook?
#
# * The different versions of `is_anagram` show that, when inputs are small, it is hard to say which algorithm will be the fastest. It often depends on details of the implementation. Anyway, the differences tend to be small, so it might not matter much in practice.
#
# * The different algorithms we used to search for anagram pairs show that, when inputs are large, we can often tell which algorithm will be fastest. And the difference between a fast algorithm and a slow one can be huge!

# %% [markdown]
# ## Exercises
#
# Before you work on these exercises, you might want to read the Python [Sorting How-To](https://docs.python.org/3/howto/sorting.html). It uses `lambda` to define an anonymous function, which [you can read about here](https://www.w3schools.com/python/python_lambda.asp).
#
# **Exercise 7:**
# Make a dictionary like `anagram_map` that contains only keys that map to a list with more than one element. You can use a `for` loop to make a new dictionary, or a [dictionary comprehension](https://www.freecodecamp.org/news/dictionary-comprehension-in-python-explained-with-examples/).

# %%
d = is_anagram(word_list)
goodlist = []
num = 3
word = ''
for key in d:
    if len(key)>=num:
        goodlist.append(key)

print(goodlist)

# %% [markdown]
# **Exercise 8:**
# Find the longest word with at least one anagram. Suggestion: use the `key` argument of `sort` or `sorted` ([see here](https://stackoverflow.com/questions/8966538/syntax-behind-sortedkey-lambda)).

# %%
d = is_anagram(word_list)
num = 0
word = ''
gulp = []
for item in d:
    for i in item:
        if len(i)>num:
            num = len(i)
            word = i
            gulp = item

print(word)
print(gulp)
# Out:
# permissiveness's
# ["permissiveness's", "impressiveness's"]

# %% [markdown]
# **Exercise 9:**
# Find the largest list of words that are anagrams of each other.

# %%
d = is_anagram(word_list)
num = 0
word = ''
for key in d:
    f = str(key)
    if len(f)>num:
        num = len(f)
        word = f

print(word)
# Out:
# ['tesla', 'tales', 'steal', 'slate', 'stale', 'least', 'stael', 'teals']

# %% [markdown]
# **Exercise 10:**
# Write a function that takes an integer `word_length` and finds the longest list of words with the given length that are anagrams of each other.

# %%
d = is_anagram(word_list)
word_length = 8
counter = 0
gulp = []
for item in d:
    for i in item:
        if len(i)==word_length:
            if len(item)>counter:
                counter = len(item)
                gulp = item


print(gulp)
# Out:
# ['ingrates', 'rangiest', 'gantries', 'angriest', 'tasering', 'tangiers']

# %% [markdown]
# **Exercise 11:**
# At this point we have a data structure that contains lists of words that are anagrams, but we have not actually enumerated all pairs.
# Write a function that takes `anagram_map` and returns a list of all anagram pairs.
# How many are there?

# %%
d = is_anagram(word_list)
print("there are " + str(len(d))+ " pairs")
# Out:
# there are 5872 pairs

# %% [markdown]
# *Data Structures and Information Retrieval in Python*
#
# Copyright 2021 Allen Downey
#
# License: [Creative Commons Attribution-NonCommercial-ShareAlike 4.0 International](https://creativecommons.org/licenses/by-nc-sa/4.0/)
